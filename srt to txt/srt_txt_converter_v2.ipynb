# %%
import os
import re
from typing import List, Optional

def read_srt_file(file_path: str) -> List[str]:
    """
    Reads the lines of an SRT file.
    
    Args:
        file_path (str): Path to the SRT file
        
    Returns:
        List[str]: Lines from the SRT file
        
    Raises:
        FileNotFoundError: If the file doesn't exist
        UnicodeDecodeError: If the file encoding is not UTF-8
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as subtitle:
            return subtitle.readlines()
    except UnicodeDecodeError:
        # Fallback to latin-1 encoding if UTF-8 fails
        with open(file_path, 'r', encoding='latin-1') as subtitle:
            return subtitle.readlines()

def extract_text_from_srt(lines: List[str]) -> str:
    """
    Extracts text from SRT lines while ignoring numerical counters and timestamps.
    
    Args:
        lines (List[str]): Lines from the SRT file
        
    Returns:
        str: Extracted text as a single paragraph
    """
    paragraph_lines = []
    # Updated timestamp patterns to handle both formats:
    # 1. HH:MM:SS,mmm --> HH:MM:SS,mmm
    # 2. HH:MM:SS --> HH:MM:SS
    timestamp_patterns = [
        re.compile(r'^\d{1,2}:\d{2}:\d{2}[,\.]\d{1,3}\s*-->\s*\d{1,2}:\d{2}:\d{2}[,\.]\d{1,3}'),
        re.compile(r'^\d{1,2}:\d{2}:\d{2}\s*-->\s*\d{1,2}:\d{2}:\d{2}')
    ]
    
    for line in lines:
        stripped_line = line.strip()
        # Skip empty lines
        if not stripped_line:
            continue
        # Skip timestamp lines using both patterns
        if any(pattern.match(stripped_line) for pattern in timestamp_patterns):
            continue
        # Skip subtitle number lines
        if stripped_line.isdigit():
            continue
        # Skip lines with common subtitle formatting tags
        if re.match(r'^<.*>$', stripped_line):
            continue
        # Remove any HTML-style formatting tags
        cleaned_line = re.sub(r'<[^>]+>', '', stripped_line)
        # Append meaningful text
        if cleaned_line:
            paragraph_lines.append(cleaned_line)
    
    # Join lines with proper spacing
    paragraph = ' '.join(paragraph_lines)
    # Clean up multiple spaces
    paragraph = re.sub(r'\s+', ' ', paragraph)
    return paragraph.strip()

def srt_to_txt(file_path: str, output_file: str) -> bool:
    """
    Converts SRT file to TXT file containing a single paragraph of text.
    
    Args:
        file_path (str): Path to the input SRT file
        output_file (str): Path for the output TXT file
        
    Returns:
        bool: True if conversion was successful, False otherwise
    """
    try:
        lines = read_srt_file(file_path)
        paragraph = extract_text_from_srt(lines)
        
        if not paragraph:
            print(f"Warning: No text content extracted from {file_path}")
            return False
            
        with open(output_file, 'w', encoding='utf-8') as new_file:
            new_file.write(paragraph)
        print(f"Successfully converted: {file_path} -> {output_file}")
        return True
    except Exception as e:
        print(f"Error converting {file_path}: {str(e)}")
        return False

def process_srt_files(folder_path: str, language_filter: Optional[str] = None) -> None:
    """
    Processes SRT files in the folder based on the language filter.
    
    Args:
        folder_path (str): Path to the folder containing SRT files
        language_filter (Optional[str]): Language tag to filter files (e.g., 'lang_en')
    """
    if not os.path.isdir(folder_path):
        print(f"Error: '{folder_path}' is not a valid directory")
        return
        
    try:
        processed_files = 0
        successful_conversions = 0
        
        for file in os.listdir(folder_path):
            if file.endswith(".srt") and (language_filter is None or language_filter in file):
                processed_files += 1
                file_path = os.path.join(folder_path, file)
                output_file = os.path.join(folder_path, file.replace('.srt', '.txt'))
                
                if srt_to_txt(file_path, output_file):
                    successful_conversions += 1
        
        if processed_files == 0:
            print(f"No matching SRT files found in {folder_path}")
            if language_filter:
                print(f"Note: Using language filter '{language_filter}'")
        else:
            print(f"\nProcessing complete:")
            print(f"Total files processed: {processed_files}")
            print(f"Successful conversions: {successful_conversions}")
            print(f"Failed conversions: {processed_files - successful_conversions}")
            
    except Exception as e:
        print(f"Error processing files: {str(e)}")

def main():
    while True:
        folder_path = input("Enter Folder Path (or 'q' to quit): ").strip()
        
        if folder_path.lower() == 'q':
            break
            
        if not os.path.isdir(folder_path):
            print(f"Error: '{folder_path}' is not a valid directory")
            continue
            
        multiple_languages = input("Are there SRT files for multiple languages? (yes/no): ").strip().lower()
        
        if multiple_languages == 'yes':
            language_filter = input("Enter the language tag to filter files (e.g., 'lang_en'): ").strip()
            print(f"\nProcessing files with the language tag '{language_filter}'...")
            process_srt_files(folder_path, language_filter)
        else:
            print("\nProcessing all SRT files in the folder...")
            process_srt_files(folder_path)
        
        print("\n" + "="*50 + "\n")

if __name__ == "__main__":
    main()
# Out:
# Enter Folder Path (or 'q' to quit):  D:\English\Impact Theory Podcasts
# Are there SRT files for multiple languages? (yes/no):  no
# Processing all SRT files in the folder...
# Successfully converted: D:\English\Impact Theory Podcasts\Be More PRODUCTIVE, PRIORITIZE Your Time, and Get Things DONE!.srt -> D:\English\Impact Theory Podcasts\Be More PRODUCTIVE, PRIORITIZE Your Time, and Get Things DONE!.txt
#
# Processing complete:
# Total files processed: 1
# Successful conversions: 1
# Failed conversions: 0
#
# ==================================================
# Enter Folder Path (or 'q' to quit):  D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning
# Are there SRT files for multiple languages? (yes/no):  yes
# Enter the language tag to filter files (e.g., 'lang_en'):  lang_en
# Processing files with the language tag 'lang_en'...
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\1 - ND065 AWSND C1 L02 A01 What Is Machine Learning V1 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\1 - ND065 AWSND C1 L02 A01 What Is Machine Learning V1 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\10 - ND065 AWSND C1 L02 A09 Steps Of ML Model Inference V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\10 - ND065 AWSND C1 L02 A09 Steps Of ML Model Inference V2 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\11 - ND065 AWSND C1 L02 A10 Examples Introduction V1 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\11 - ND065 AWSND C1 L02 A10 Examples Introduction V1 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\12 - ND065 AWSND C1 L02 A11 Example 1 V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\12 - ND065 AWSND C1 L02 A11 Example 1 V2 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\13 - ND065 AWSND C1 L02 A12 Example 2 V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\13 - ND065 AWSND C1 L02 A12 Example 2 V2 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\14 - ND065 AWSND C1 L02 A13 Example 3 V3 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\14 - ND065 AWSND C1 L02 A13 Example 3 V3 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\15 - ND065 AWSND C1 L02 A14 Lesson Review V2 Copy 01 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\15 - ND065 AWSND C1 L02 A14 Lesson Review V2 Copy 01 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\2 - ND065 AWSND C1 L02 A02 Lesson Outline V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\2 - ND065 AWSND C1 L02 A02 Lesson Outline V2 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\3 - ND065 AWSND C1 L02 A03 What Is Machine Learning Cont Part1 V3 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\3 - ND065 AWSND C1 L02 A03 What Is Machine Learning Cont Part1 V3 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\4 - ND065 AWSND C1 L02 A03b What Is Machine Learning Cont Part2 V3 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\4 - ND065 AWSND C1 L02 A03b What Is Machine Learning Cont Part2 V3 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\5 - ND065 AWSND C1 L02 A04 Steps Of Machine Learning V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\5 - ND065 AWSND C1 L02 A04 Steps Of Machine Learning V2 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\6 - ND065 AWSND C1 L02 A05 Steps Of ML Defining Problem V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\6 - ND065 AWSND C1 L02 A05 Steps Of ML Defining Problem V2 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\7 - ND065 AWSND C1 L02 A06 Steps Of ML Build Dataset V3 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\7 - ND065 AWSND C1 L02 A06 Steps Of ML Build Dataset V3 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\8 - ND065 AWSND C1 L02 A07 Steps Of ML Model Training V3 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\8 - ND065 AWSND C1 L02 A07 Steps Of ML Model Training V3 - lang_en.txt
# Successfully converted: D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\9 - ND065 AWSND C1 L02 A08 Steps Of ML Model Evaluation V2 - lang_en.srt -> D:\Machine Learning\AWS Machine Learning Foundations Course\1 - Introduction+to+Machine+Learning\9 - ND065 AWSND C1 L02 A08 Steps Of ML Model Evaluation V2 - lang_en.txt
#
# Processing complete:
# Total files processed: 15
# Successful conversions: 15
# Failed conversions: 0
#
# ==================================================
# Enter Folder Path (or 'q' to quit):  q
