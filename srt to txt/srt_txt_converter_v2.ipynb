# %%
import os
import re

def read_srt_file(file_path):
    """
    Reads the lines of an SRT file.
    """
    with open(file_path, 'r', encoding='utf-8') as subtitle:
        return subtitle.readlines()

def extract_text_from_srt(lines):
    """
    Extracts text from SRT lines while ignoring numerical counters and timestamps.
    """
    paragraph_lines = []
    timestamp_pattern = re.compile(r'^\d{2}:\d{2}:\d{2} --> \d{2}:\d{2}:\d{2}')

    for line in lines:
        stripped_line = line.strip()
        # Ignore lines with timestamps
        if timestamp_pattern.match(stripped_line):
            continue
        # Ignore lines that are purely numeric counters
        if stripped_line.isdigit():
            continue
        # Append meaningful text
        if stripped_line:
            paragraph_lines.append(stripped_line)
    
    # Join all lines into a single paragraph
    paragraph = ' '.join(paragraph_lines)
    return paragraph

def srt_to_txt(file_path, output_file):
    """
    Converts SRT file to TXT file containing a single paragraph of text.
    """
    try:
        lines = read_srt_file(file_path)
        paragraph = extract_text_from_srt(lines)
        
        with open(output_file, 'w', encoding='utf-8') as new_file:
            new_file.write(paragraph)
        print(f"Converted: {file_path} -> {output_file}")
    except Exception as e:
        print(f"Error converting {file_path}: {e}")

def process_srt_files(folder_path, language_filter=None):
    """
    Processes SRT files in the folder based on the language filter.
    If no language filter is provided, processes all SRT files.
    """
    try:
        for file in os.listdir(folder_path):
            # Check if file is an SRT file and optionally matches the language filter
            if file.endswith(".srt") and (language_filter is None or language_filter in file):
                file_path = os.path.join(folder_path, file)
                output_file = os.path.join(folder_path, file.replace('.srt', '.txt'))
                srt_to_txt(file_path, output_file)
    except Exception as e:
        print(f"Error processing files: {e}")

if __name__ == "__main__":
    again = 'y'
    while again.lower() == 'y':
        folder_path = input("Enter Folder Path: ").strip()
        
        # Ask the user if there are multiple languages
        multiple_languages = input("Are there SRT files for multiple languages? (yes/no): ").strip().lower()
        
        if multiple_languages == 'yes':
            language_filter = input("Enter the language tag to filter files (e.g., 'lang_en'): ").strip()
            print(f"Processing files with the language tag '{language_filter}'...")
            process_srt_files(folder_path, language_filter)
        else:
            print("Processing all SRT files in the folder...")
            process_srt_files(folder_path)
        
        again = input("Again? (y or n): ").strip()
# Out:
# Enter Folder Path:  D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos
# Are there SRT files for multiple languages? (yes/no):  no
# Processing all SRT files in the folder...
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\01_Welcome.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\01_Welcome.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\02_What is Excel.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\02_What is Excel.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\03_About Course.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\03_About Course.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\04_Excel Install.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\04_Excel Install.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\05_Worksheets.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\05_Worksheets.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\06_Workbooks.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\06_Workbooks.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\07_Ribbon.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\07_Ribbon.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\08_Formulas Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\08_Formulas Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\09_Function Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\09_Function Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\10_Logical Functions.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\10_Logical Functions.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\11_Math Functions.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\11_Math Functions.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\12_Statistical Functions.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\12_Statistical Functions.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\13_Array Formulas.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\13_Array Formulas.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\14_Lookup Function.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\14_Lookup Function.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\15_Text Functions.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\15_Text Functions.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\16_Date and Time Functions.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\16_Date and Time Functions.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\17_Charts Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\17_Charts Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\18_Charts Advanced.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\18_Charts Advanced.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\19_Charts Statistics.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\19_Charts Statistics.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\20_Sparklines.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\20_Sparklines.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\21_Tables.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\21_Tables.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\22_Formatting.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\22_Formatting.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\23_Collaboration.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\23_Collaboration.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\24_Project #1 Build Dashboard.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\24_Project #1 Build Dashboard.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\25_Project #1 Share Projects.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\25_Project #1 Share Projects.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\26_PivotTable Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\26_PivotTable Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\27_PivotTable Advanced.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\27_PivotTable Advanced.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\28_PivotCharts.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\28_PivotCharts.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\29_Analysis Add-ins.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\29_Analysis Add-ins.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\30_Data Tables.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\30_Data Tables.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\31_Analysis ToolPak.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\31_Analysis ToolPak.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\32_Power Query Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\32_Power Query Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\33_Power Query Editor.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\33_Power Query Editor.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\34_Advanced Transformations.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\34_Advanced Transformations.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\35_Append vs Merge.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\35_Append vs Merge.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\36_M Language.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\36_M Language.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\37_Power Pivot Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\37_Power Pivot Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\38_Power Pivot Window.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\38_Power Pivot Window.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\39_DAX Intro.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\39_DAX Intro.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\40_DAX Advanced.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\40_DAX Advanced.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\41_Project #2 Share w Git & GitHub.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\41_Project #2 Share w Git & GitHub.txt
# Converted: D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\42_Project #2 Document w README.md.srt -> D:\Data Analysis\Excel for Data Analytics - Full Course for Beginners\Excel for Data Analytics - Videos\42_Project #2 Document w README.md.txt
# Again? (y or n):  n
